# %%
import pandas as pd

# %% [markdown]
# # 1. 读取csv数据·

# %%
# 1. 读取csv数据
df = pd.read_csv('./数据集/stock_day.csv', sep = ',', usecols = ['open', 'high', 'low', 'close'])
df

# %%
# 2. 把读取到的数据，写到文件中
df[:10].to_csv('./数据集/my_file1.csv', sep = ',', index = False)
print('写入成功')

# %%
# 3. 特殊的csv文件——>tsv文件
df[:5].to_csv('./数据集/my_file2.tsv', sep = '\t', index = True)
print('写入成功')
# Out:
# 写入成功

# %%
# 4. 把读取tsv文件
df = pd.read_csv('./数据集/my_file2.tsv', sep = '\t', index_col = 0)
df
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48
