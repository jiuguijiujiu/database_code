# %%
import numpy as np

# %% [markdown]
# # 1. 演示numpy基本函数

# %%
# 1. 创建一个标准的正态分布序列
arr1 = np.random.randn(3, 5)
print(arr1)

# %%
# 2. 基本函数
# print(np.ceil(arr1))
# print(np.floor(arr1))
# print(np.rint(arr1))
# print(np.isnan(arr1))
# print(np.abs(arr1))
# print(np.multiply(arr1, arr1))
# print(np.divide(arr1, arr1))
print(np.where(arr1 > 0, arr1, -arr1))
# Out:
# [[0.97967914 0.44005135 1.10108745 0.78926289 0.95097729]
#  [0.36101082 1.77266867 0.70498055 0.32773109 1.2824957 ]
#  [0.83545506 1.25515665 0.65870327 0.30356751 0.78346869]]
