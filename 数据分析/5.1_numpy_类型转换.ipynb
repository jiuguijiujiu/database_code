# %%
import numpy as np

# %% [markdown]
# # 1. numpy类型转换，astype()

# %%
# 1. 创建ndarray类型
arr1 = np.arange(0, 10, 2, dtype = np.int32)
print(arr1)
print(arr1.dtype)
# Out:
# [0 2 4 6 8]
# int32

# %%
# 2. 转换类型
arr2 = arr1.astype(np.float64)
print(arr2)
print(arr2.dtype)
# Out:
# [0. 2. 4. 6. 8.]
# float64
