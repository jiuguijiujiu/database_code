# %%
import pandas as pd

# %%
# 1. 加载数据
df = pd.read_csv('./数据集/1960-2019全球GDP数据.csv', encoding='gbk')
df

# %%
# 2. 拷贝一份原始数据出来进行操作
df2 = df[:5].copy()
df2

# %%
# 3. 新增一列
df2['c1'] = 23
df2

# %%
# 4. 修改gpd值
df2['GDP'] = [0, 1, 2, 3, 4]
df2

# %%
# 5. 采用replace（）替换

# 美国——>usa
df2.country.replace('美国', 'usa', inplace=True)

# 日本——>jp
df2.country.replace('日本', 'jp', inplace=True)

df2
# Out:
#    year country           GDP
# 0  1960     usa  543300000000
# 1  1960      英国   73233967692
# 2  1960      法国   62225478000
# 3  1960      中国   59716467625
# 4  1960      jp   44307342950
