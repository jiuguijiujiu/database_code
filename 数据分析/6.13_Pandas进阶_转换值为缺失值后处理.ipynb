# %%
import pandas as pd
import numpy as np

# %%
# 1. 加载数据集
wis = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data")
wis

# %%
# 2. 尝试直接删除缺失值
wis.dropna()    # 删不掉，因为？不是缺失值nan

# %%
# 3. ？——>nan——>删除缺失值
wis.replace('?', np.nan).dropna()
