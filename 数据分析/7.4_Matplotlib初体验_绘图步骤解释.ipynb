# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. matplotlib入门案例——绘制北京温度折线图

# %%
# 1. 创建画布
plt.figure(figsize=(10, 5), dpi=100)

# 2. 准备数据（x轴，y轴）
plt.plot([1, 2, 3, 4, 5, 6, 7],[15, 11, 19, 5, 21, 28, 22])

# 3. 显示图像
plt.show()
